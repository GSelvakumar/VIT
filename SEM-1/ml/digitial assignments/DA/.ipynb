# %% [markdown]
# ## K-means Clustering and Agglomerative Clustering

# %%
import numpy as nm    
import matplotlib.pyplot as mtp    
import pandas as pd

# %%
dataset = pd.read_csv("Mall_Customers.csv")
dataset[:5]
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Extracting independent variables
x = dataset.iloc[:, [3, 4]].values

# %%
x[:5]
# Out:
# array([[15, 39],
#        [15, 81],
#        [16,  6],
#        [16, 77],
#        [17, 40]])

# %%
#finding optimal number of clusters using the elbow method  
from sklearn.cluster import KMeans  
wcss_list= []  #Initializing the list for the values of WCSS  
  
#Using for loop for iterations from 1 to 10.  
for i in range(1, 11):  
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state= 42)  
    kmeans.fit(x)  
    wcss_list.append(kmeans.inertia_)  
mtp.plot(range(1, 11), wcss_list)  
mtp.title('The Elobw Method Graph')  
mtp.xlabel('Number of clusters(k)')  
mtp.ylabel('wcss_list')  
mtp.show()

# %%
#training the K-means model on a dataset  
kmeans = KMeans(n_clusters=5, init='k-means++', random_state= 42)  
y_predict= kmeans.fit_predict(x)

# %%
#visulaizing the clusters  
mtp.scatter(x[y_predict == 0, 0], x[y_predict == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') #for first cluster  
mtp.scatter(x[y_predict == 1, 0], x[y_predict == 1, 1], s = 100, c = 'green', label = 'Cluster 2') #for second cluster  
mtp.scatter(x[y_predict== 2, 0], x[y_predict == 2, 1], s = 100, c = 'red', label = 'Cluster 3') #for third cluster  
mtp.scatter(x[y_predict == 3, 0], x[y_predict == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') #for fourth cluster  
mtp.scatter(x[y_predict == 4, 0], x[y_predict == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5') #for fifth cluster  
mtp.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroid')   
mtp.title('Clusters of customers')  
mtp.xlabel('Annual Income (k$)')  
mtp.ylabel('Spending Score (1-100)')  
mtp.legend()  
mtp.show()

# %%
# import
from sklearn.cluster import AgglomerativeClustering

# %%
aggloclus = AgglomerativeClustering(n_clusters = 5)

# %%
y_predict = aggloclus.fit_predict(x)

# %%
mtp.scatter(x[y_predict == 0, 0], x[y_predict == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') #for first cluster  
mtp.scatter(x[y_predict == 1, 0], x[y_predict == 1, 1], s = 100, c = 'green', label = 'Cluster 2') #for second cluster  
mtp.scatter(x[y_predict== 2, 0], x[y_predict == 2, 1], s = 100, c = 'red', label = 'Cluster 3') #for third cluster  
mtp.scatter(x[y_predict == 3, 0], x[y_predict == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') #for fourth cluster  
mtp.scatter(x[y_predict == 4, 0], x[y_predict == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5') #for fifth cluster     
mtp.title('Clusters of customers')  
mtp.xlabel('Annual Income (k$)')  
mtp.ylabel('Spending Score (1-100)')  
mtp.legend()  
mtp.show()

# %% [markdown]
# ## linkage measure

# %%
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("new_mall_customers.csv")

# %%
dataset[:5]
# Out:
#    Annual Income(k$)  Spending Score (1-100)
# 0                 75                       9
# 1                 50                      17
# 2                 74                      73
# 3                 40                      63
# 4                 66                      59

# %%
x = dataset.iloc[:, :].values
x[:5]
# Out:
# array([[75,  9],
#        [50, 17],
#        [74, 73],
#        [40, 63],
#        [66, 59]])

# %%
model_single = AgglomerativeClustering(n_clusters = 5, linkage="single")
model_complete = AgglomerativeClustering(n_clusters = 5, linkage="complete")
model_average = AgglomerativeClustering(n_clusters = 5, linkage="average")

# %%
single_predict = model_single.fit_predict(x)
complete_predict = model_complete.fit_predict(x)
average_predict = model_average.fit_predict(x)

# %%
plt.scatter(x[single_predict == 0, 0], x[single_predict == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') #for first cluster  
plt.scatter(x[single_predict == 1, 0], x[single_predict == 1, 1], s = 100, c = 'green', label = 'Cluster 2') #for second cluster  
plt.scatter(x[single_predict== 2, 0], x[single_predict == 2, 1], s = 100, c = 'red', label = 'Cluster 3') #for third cluster  
plt.scatter(x[single_predict == 3, 0], x[single_predict == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') #for fourth cluster  
plt.scatter(x[single_predict == 4, 0], x[single_predict == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5') #for fifth cluster     
plt.title('Clusters of customers[Single linkage]')  
plt.xlabel('Annual Income (k$)')  
plt.ylabel('Spending Score (1-100)')  
plt.legend()  
plt.show()

# %%
plt.scatter(x[complete_predict == 0, 0], x[complete_predict == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') #for first cluster  
plt.scatter(x[complete_predict == 1, 0], x[complete_predict == 1, 1], s = 100, c = 'green', label = 'Cluster 2') #for second cluster  
plt.scatter(x[complete_predict== 2, 0], x[complete_predict == 2, 1], s = 100, c = 'red', label = 'Cluster 3') #for third cluster  
plt.scatter(x[complete_predict == 3, 0], x[complete_predict == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') #for fourth cluster  
plt.scatter(x[complete_predict == 4, 0], x[complete_predict == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5') #for fifth cluster     
plt.title('Clusters of customers[Complete Linkage]')  
plt.xlabel('Annual Income (k$)')  
plt.ylabel('Spending Score (1-100)')  
plt.legend()  
plt.show()

# %%
plt.scatter(x[average_predict == 0, 0], x[average_predict == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') #for first cluster  
plt.scatter(x[average_predict == 1, 0], x[average_predict == 1, 1], s = 100, c = 'green', label = 'Cluster 2') #for second cluster  
plt.scatter(x[average_predict== 2, 0], x[average_predict == 2, 1], s = 100, c = 'red', label = 'Cluster 3') #for third cluster  
plt.scatter(x[average_predict == 3, 0], x[average_predict == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') #for fourth cluster  
plt.scatter(x[average_predict == 4, 0], x[average_predict == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5') #for fifth cluster     
plt.title('Clusters of customers[Average Linkage]')  
plt.xlabel('Annual Income (k$)')  
plt.ylabel('Spending Score (1-100)')  
plt.legend()  
plt.show()

# %% [markdown]
# ## Birch Clustering

# %%
# Import
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import Birch

# %%
# Generating 600 samples using make_blobs
dataset, clusters = make_blobs(n_samples = 600, centers = 8, cluster_std = 0.75, random_state = 0)

# %%
# Creating the BIRCH clustering model
model = Birch(branching_factor = 50, n_clusters = None, threshold = 1.5)

# %%
# Fit the data (Training)
model.fit(dataset)
# Out:
# Birch(n_clusters=None, threshold=1.5)

# %%
# Predict the same data
pred = model.predict(dataset)

# %%
# Creating a scatter plot
plt.scatter(dataset[:, 0], dataset[:, 1], c = pred, cmap = 'rainbow', alpha = 0.7, edgecolors = 'b')
plt.show()

# %% [markdown]
# ## Bagging and Boosting

# %%
import pandas as pd
import numpy as np
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")

# %%
pima = pd.read_csv("diabetes.csv", header=0)
pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# split data into X and y
X = pima.iloc[:,0:8]
Y = pima.iloc[:,8]

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
# split data into train and test sets
seed = 42
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 73.59%

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model2 = AdaBoostClassifier()
model2.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred2 = model2.predict(X_test)
predictions2 = [round(value) for value in y_pred2]

# %%
accuracy2 = accuracy_score(y_test, predictions2)
print("Accuracy: %.2f%%" % (accuracy2 * 100.0))
# Out:
# Accuracy: 74.46%

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model3 = GradientBoostingClassifier()
model3.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred3 = model3.predict(X_test)
predictions3 = [round(value) for value in y_pred3]

# %%
accuracy3 = accuracy_score(y_test, predictions3)
print("Accuracy: %.2f%%" % (accuracy3 * 100.0))
# Out:
# Accuracy: 74.89%
